# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("results.csv")
data
# Out:
#    NumThreads  BlockSize   Time
# 0           1     195958  33388
# 1           2      97979  22345
# 2           3      65319  19434
# 3           4      48989  16354
# 4           5      39191  15524
# 5           6      32659  15703
# 6           7      27994  16000
# 7           8      24494  15448
# 8           9      21773  15790
# 9          10      19595  15248

# %%
plt.plot(data["NumThreads"], data["Time"]/1000)
plt.xlabel("N° of threads")
plt.ylabel("Time (s)")
plt.title("Processing time with multithreading")
plt.plot()
# Out:
# []
